# %%
from PixelWhisper import *

# %% [markdown]
# # working

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as compare_ssim

# %%
image = cv2.imread("/home/mahsa/Desktop/ENV/DIP_ENV/encode/Image/still-life-books-versus-technology.jpg")
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
# text, ssim,denoised_image = decode_text_from_image(noised_encoded_image, rgb_image, len(my_text))
# print("Decoded Text:", text)
# print("SSIM:", ssim)

# %%
# plt.imshow(denoised_image)

# %%
# ssim_score = compare_ssim(encoded_image, denoised_image, multichannel=True, channel_axis=-1)
# ssim_score
